# %%
from agent import *

# %%
build = (
    Build('6 Red Lexington Ranger')
    .PrimaryWeapon(
        WDCore(0.01, name='Expertise'),
        WDType(0.15, name='AR'),
        DTH(0.21, uptime=0.3),
        DTTOOC(0.10, uptime=0.9),
        AMP2(0.25, name='Ranger'),
        base_damage=48_700,
        rpm=850,
        name='Lexington',
    )
    .SecondaryWeapon(
        WDCore(0.01, name='Expertise'),
        WDType(0.15, name='AR'),
        DTH(0.21, uptime=0.3),
        DTTOOC(0.10, uptime=0.9),
        base_damage=46_900,
        rpm=850,
        name='St. Elmo\'s Engine',
    )
    .Mask(
        RedCore(),
        CHC(0.06),
        CHD(0.12),
        CHD(0.12, name='Mod.CHD'),
        CHD(0.25, uptime=0.33, name='Short.CHD'),
        CHD(0.10, uptime=0.33, name='Mid.CHD'),
        CHC(0.10, uptime=0.33, name='Mid.CHC'),
        CHC(0.25, uptime=0.33, name='Long.CHC'),
        name='Coyote',
    )
    .Backpack(
        RedCore(),
        CHC(0.06),
        CHD(0.12),
        CHD(0.12, name='Mod.CHD'),
        TWD(0.65, uptime=0.8, name='Striker'),
        ROF(0.15, name='ROF'),
        name='Striker',
    )
    .Chest(
        RedCore(),
        CHD(0.12),
        CHD(0.12, name='Mod.CHD'),
        name='Lengmo',
    )
    .Gloves(
        RedCore(),
        CHD(0.12),
        name='Striker',
    )
    .Holster(
        RedCore(),
        CHD(0.12),
        name='Striker',
    )
    .Kneepads(
        RedCore(),
        CHD(0.12),
        name='Striker',
    )
    .Specialization(
        WDType(0.15, name='Gunner.WDType')
    )
    .KeenersWatch()
)

# %%
build.dps_x.stats()
# Out:
# ----------------------------- -----------------------------
# Stats:                        Stats:
# ----------------------------- -----------------------------
# Build: 6 Red Lexington Ranger Build: 6 Red Lexington Ranger
# Weapon: Lexington:            Weapon: St. Elmo's Engine:
# ----------------------------- -----------------------------
# CHC: 44%                      CHC: 44%
# CHD: 165%                     CHD: 165%
# HS: 75%                       HS: 75%
# HSC: 20%                      HSC: 20%
# ----------------------------- -----------------------------

# %%
build.dps_x.gradients()
# Out:
# ------------------------------- -------------------------------
# DPSx Gradients:                 DPSx Gradients:
# ------------------------------- -------------------------------
# Build: 6 Red Lexington Ranger   Build: 6 Red Lexington Ranger
# ------------------------------- -------------------------------
# Weapon: Lexington               Weapon: St. Elmo's Engine
#   Expertise 1.0%      :  4.7257   Expertise 1.0%      :  3.7806
#   AR 15.0%            :  4.7257   AR 15.0%            :  3.7806
#   DTH 21.0%           :  3.0808   DTH 21.0%           :  2.4647
#   DTTOOC 10.0%        :  9.0135   DTTOOC 10.0%        :  7.2108
#   Ranger 25.0%        :  8.7331 -------------------------------
# ------------------------------- Mask: Coyote
# Mask: Coyote                      RedCore 15.0%       :  3.7806
#   RedCore 15.0%       :  4.7257   CHC 6.0%            :  7.6986
#   CHC 6.0%            :  9.6232   CHD 12.0%           :  2.0375
#   CHD 12.0%           :  2.5469   Mod.CHD 12.0%       :  2.0375
#   Mod.CHD 12.0%       :  2.5469   Short.CHD 25.0%     :  0.6724
#   Short.CHD 25.0%     :  0.8405   Mid.CHD 10.0%       :  0.6724
#   Mid.CHD 10.0%       :  0.8405   Mid.CHC 10.0%       :  2.5405
#   Mid.CHC 10.0%       :  3.1757   Long.CHC 25.0%      :  2.5405
#   Long.CHC 25.0%      :  3.1757 -------------------------------
# ------------------------------- Backpack: Striker
# Backpack: Striker                 RedCore 15.0%       :  3.7806
#   RedCore 15.0%       :  4.7257   CHC 6.0%            :  7.6986
#   CHC 6.0%            :  9.6232   CHD 12.0%           :  2.0375
#   CHD 12.0%           :  2.5469   Mod.CHD 12.0%       :  2.0375
#   Mod.CHD 12.0%       :  2.5469   Striker 65.0%       :  4.5964
#   Striker 65.0%       :  5.7455   ROF 15.0%           :  7.5940
#   ROF 15.0%           :  9.4925 -------------------------------
# ------------------------------- Chest: Lengmo
# Chest: Lengmo                     RedCore 15.0%       :  3.7806
#   RedCore 15.0%       :  4.7257   CHD 12.0%           :  2.0375
#   CHD 12.0%           :  2.5469   Mod.CHD 12.0%       :  2.0375
#   Mod.CHD 12.0%       :  2.5469 -------------------------------
# ------------------------------- Gloves: Striker
# Gloves: Striker                   RedCore 15.0%       :  3.7806
#   RedCore 15.0%       :  4.7257   CHD 12.0%           :  2.0375
#   CHD 12.0%           :  2.5469 -------------------------------
# ------------------------------- Holster: Striker
# Holster: Striker                  RedCore 15.0%       :  3.7806
#   RedCore 15.0%       :  4.7257   CHD 12.0%           :  2.0375
#   CHD 12.0%           :  2.5469 -------------------------------
# ------------------------------- Kneepads: Striker
# Kneepads: Striker                 RedCore 15.0%       :  3.7806
#   RedCore 15.0%       :  4.7257   CHD 12.0%           :  2.0375
#   CHD 12.0%           :  2.5469 -------------------------------
# ------------------------------- Specialization: Specialization
# Specialization: Specialization    Gunner.WDType 15.0% :  3.7806
#   Gunner.WDType 15.0% :  4.7257 -------------------------------
# ------------------------------- Watch: KeenersWatch
# Watch: KeenersWatch               Watch.WD 10.0%      :  3.7806
#   Watch.WD 10.0%      :  4.7257   CHC 10.0%           :  7.6986
#   CHC 10.0%           :  9.6232   CHD 20.0%           :  2.0375
#   CHD 20.0%           :  2.5469   HS 20.0%            :  0.9357
#   HS 20.0%            :  1.1696 -------------------------------
# -------------------------------

# %%
build.dps.delta()
# Out:
# ---------------------------------- ----------------------------------
# DPS Delta:                         DPS Delta:
# ---------------------------------- ----------------------------------
# Build: 6 Red Lexington Ranger      Build: 6 Red Lexington Ranger
# ---------------------------------- ----------------------------------
# Weapon: Lexington                  Weapon: St. Elmo's Engine
#   Expertise 1.0%      :     32,603   Expertise 1.0%      :     25,119
#   AR 15.0%            :    489,051   AR 15.0%            :    376,780
#   DTH 21.0%           :    446,357   DTH 21.0%           :    343,887
#   DTTOOC 10.0%        :    621,857   DTTOOC 10.0%        :    479,098
#   Ranger 25.0%        :  1,506,276 ----------------------------------
# ---------------------------------- Mask: Coyote
# Mask: Coyote                         RedCore 15.0%       :    376,780
#   RedCore 15.0%       :    489,051   CHC 6.0%            :    306,904
#   CHC 6.0%            :    398,354   CHD 12.0%           :    162,451
#   CHD 12.0%           :    210,858   Mod.CHD 12.0%       :    162,451
#   Mod.CHD 12.0%       :    210,858   Short.CHD 25.0%     :    111,685
#   Short.CHD 25.0%     :    144,965   Mid.CHD 10.0%       :     44,674
#   Mid.CHD 10.0%       :     57,986   Mid.CHC 10.0%       :    168,797
#   Mid.CHC 10.0%       :    219,095   Long.CHC 25.0%      :    421,993
#   Long.CHC 25.0%      :    547,736 ----------------------------------
# ---------------------------------- Backpack: Striker
# Backpack: Striker                    RedCore 15.0%       :    376,780
#   RedCore 15.0%       :    489,051   CHC 6.0%            :    306,904
#   CHC 6.0%            :    398,354   CHD 12.0%           :    162,451
#   CHD 12.0%           :    210,858   Mod.CHD 12.0%       :    162,451
#   Mod.CHD 12.0%       :    210,858   Striker 65.0%       :  1,985,035
#   Striker 65.0%       :  2,576,525   ROF 15.0%           :    756,836
#   ROF 15.0%           :    982,354 ----------------------------------
# ---------------------------------- Chest: Lengmo
# Chest: Lengmo                        RedCore 15.0%       :    376,780
#   RedCore 15.0%       :    489,051   CHD 12.0%           :    162,451
#   CHD 12.0%           :    210,858   Mod.CHD 12.0%       :    162,451
#   Mod.CHD 12.0%       :    210,858 ----------------------------------
# ---------------------------------- Gloves: Striker
# Gloves: Striker                      RedCore 15.0%       :    376,780
#   RedCore 15.0%       :    489,051   CHD 12.0%           :    162,451
#   CHD 12.0%           :    210,858 ----------------------------------
# ---------------------------------- Holster: Striker
# Holster: Striker                     RedCore 15.0%       :    376,780
#   RedCore 15.0%       :    489,051   CHD 12.0%           :    162,451
#   CHD 12.0%           :    210,858 ----------------------------------
# ---------------------------------- Kneepads: Striker
# Kneepads: Striker                    RedCore 15.0%       :    376,780
#   RedCore 15.0%       :    489,051   CHD 12.0%           :    162,451
#   CHD 12.0%           :    210,858 ----------------------------------
# ---------------------------------- Specialization: Specialization
# Specialization: Specialization       Gunner.WDType 15.0% :    376,780
#   Gunner.WDType 15.0% :    489,051 ----------------------------------
# ---------------------------------- Watch: KeenersWatch
# Watch: KeenersWatch                  Watch.WD 10.0%      :    251,187
#   Watch.WD 10.0%      :    326,034   CHC 10.0%           :    511,507
#   CHC 10.0%           :    663,923   CHD 20.0%           :    270,752
#   CHD 20.0%           :    351,429   HS 20.0%            :    124,341
#   HS 20.0%            :    161,391 ----------------------------------
# ----------------------------------
